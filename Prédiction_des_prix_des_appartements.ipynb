# %%
import pandas as pd
# Load my dataset
avito_data = pd.read_csv('/content/drive/MyDrive/DataSet/merged_data_csv.csv', encoding='latin1')
avito_data
# Out:
#                                               House Name             Prix  \
# 0                                   House Name Not Found  Price Not Found
# 1                            appartement meublé à louer          5 000 DH
# 2                                   House Name Not Found  Price Not Found
# 3                Appartement à vendre 84 m² à Mohammedia     1 300 000 DH
# 4                                   House Name Not Found  Price Not Found
# ...                                                  ...              ...
# 36595  Appart 86m2 à Gueliz pour habitation ou commer...       855 000 DH
# 36596          Appartement à vendre 59 a 72 m² à louizia       380 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir     300 DH /Nuit
# 36598                  appartement en location a ifrane            350 DH
# 36599                          Appartement hamria meublé     250 DH /Nuit
#
#                                              Équipements  \
# 0                             équipements non mentionnés
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 2                             équipements non mentionnés
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 4                             équipements non mentionnés
# ...                                                  ...
# 36595                         équipements non mentionnés
# 36596                  Balcon, Cuisine équipée, Terrasse
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
# 36598  Concierge, Sécurité, Parking, Cuisine équipée,...
# 36599                         équipements non mentionnés
#
#                                  Type           Secteur  \
# 0                                 NaN               NaN
# 1               Appartements, à louer    Sala el Jadida
# 2                                 NaN               NaN
# 3              Appartements, à vendre  Quartier du Parc
# 4                                 NaN               NaN
# ...                               ...               ...
# 36595          Appartements, à vendre            Guéliz
# 36596          Appartements, à vendre     Autre secteur
# 36597  Locations de vacances, à louer              Anza
# 36598           Appartements, à louer        La Prairie
# 36599  Locations de vacances, à louer            Hamria
#
#        Frais de syndic / mois  Surface habitable            Étage  Salons  \
# 0                         NaN                NaN              NaN     NaN
# 1                       150.0               82.0                4     1.0
# 2                         NaN                NaN              NaN     NaN
# 3                         NaN               84.0                1     1.0
# 4                         NaN                NaN              NaN     NaN
# ...                       ...                ...              ...     ...
# 36595                     NaN               86.0                3     NaN
# 36596                     NaN               72.0                2     1.0
# 36597                     NaN                NaN              NaN     NaN
# 36598                     NaN                NaN  Rez de chaussée     2.0
# 36599                     NaN                NaN              NaN     NaN
#
#       Caution Âge du bien Horaire d'arrivée Horaire de départ
# 0         NaN         NaN               NaN               NaN
# 1      2 mois         NaN               NaN               NaN
# 2         NaN         NaN               NaN               NaN
# 3         NaN        Neuf               NaN               NaN
# 4         NaN         NaN               NaN               NaN
# ...       ...         ...               ...               ...
# 36595     NaN         NaN               NaN               NaN
# 36596     NaN        Neuf               NaN               NaN
# 36597     NaN         NaN             12:00             11:00
# 36598     NaN         NaN               NaN               NaN
# 36599     NaN         NaN               NaN               NaN
#
# [36600 rows x 13 columns]

# %%
avito_data.shape
# Out:
# (36600, 13)

# %%
avito_data.columns
# Out:
# Index(['House Name', 'Prix', 'Équipements', 'Type', 'Secteur',
#        'Frais de syndic / mois', 'Surface habitable', 'Étage', 'Salons',
#        'Caution', 'Âge du bien', 'Horaire d'arrivée', 'Horaire de départ'],
#       dtype='object')

# %%
avito_data.dtypes
# Out:
# House Name                 object
# Prix                       object
# Équipements                object
# Type                       object
# Secteur                    object
# Frais de syndic / mois    float64
# Surface habitable         float64
# Étage                      object
# Salons                    float64
# Caution                    object
# Âge du bien                object
# Horaire d'arrivée          object
# Horaire de départ          object
# dtype: object

# %%
#number of duplicated lignes in my dataset
avito_data.duplicated().sum()
# Out:
# 13293

# %%
#delete all duplicates lignes
avito_data = avito_data.drop_duplicates()

# %%
avito_data.duplicated().sum()
# Out:
# 0

# %%
avito_data.shape
# Out:
# (23307, 13)

# %%
# How many null values in each col
avito_data.isnull().sum()
# Out:
# House Name                    0
# Prix                          0
# Équipements                   0
# Type                          1
# Secteur                     101
# Frais de syndic / mois    20502
# Surface habitable         11046
# Étage                     10776
# Salons                    10908
# Caution                   18762
# Âge du bien               17739
# Horaire d'arrivée         14035
# Horaire de départ         14135
# dtype: int64

# %%
avito_data.isnull().sum().sum()
# Out:
# 118005

# %% [markdown]
# At the moment when I was scraping my data from avito sit web, I make a mistake that I put a condition when it was a null value or there is no value of a column replaces with a word or a sentence like 'Prix non spécifié' etc..
# So now I will replace each character like that with a null value to have the real number of null values in my dataset to clean it and preprocecsse it.

# %%
df = avito_data
is_non_numeric = df['Prix'].apply(lambda x: pd.to_numeric(x, errors='coerce')).isna()

# Count the number of non-digital lines
nombre_de_lignes_non_numeriques = is_non_numeric.sum()

print(f"Le nombre de lignes non numériques dans la colonne 'Colonne' est : {nombre_de_lignes_non_numeriques}")
# Out:
# Le nombre de lignes non numériques dans la colonne 'Colonne' est : 23307

# %%
# Specify the values you are looking for in a list
valeurs_recherchees = ['Prix non spécifié', 'Price Not Found']

# Use the . value_counts() method to count occurrences
comptage = df['Prix'].isin(valeurs_recherchees).sum()

print(f"Les valeurs {', '.join(valeurs_recherchees)} se répètent {comptage} fois dans la colonne 'Colonne'.")
# Out:
# Les valeurs Prix non spécifié, Price Not Found se répètent 1920 fois dans la colonne 'Colonne'.

# %%
import pandas as pd
import numpy as np




# the values to replace with NaN
valeurs_recherchees = ['Prix non spécifié', 'Price Not Found']

# Use a boolean filter to identify the cells to replace with NaN
filtre = df['Prix'].isin(valeurs_recherchees)

# Replace the specified values with NaN
df.loc[filtre, 'Prix'] = np.nan

print("DataFrame original:")
print(df)
# Out:
# DataFrame original:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                             équipements non mentionnés
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  \
# 0                                 NaN               NaN
# 1               Appartements, à louer    Sala el Jadida
# 3              Appartements, à vendre  Quartier du Parc
# 6              Appartements, à vendre    Toute la ville
# 8      Locations de vacances, à louer            Guéliz
# ...                               ...               ...
# 36588          Appartements, à vendre          Harhoura
# 36590           Appartements, à louer        La Prairie
# 36591          Appartements, à vendre          Harhoura
# 36592          Appartements, à vendre           Mimosas
# 36597  Locations de vacances, à louer              Anza
#
#        Frais de syndic / mois  Surface habitable Étage  Salons Caution  \
# 0                         NaN                NaN   NaN     NaN     NaN
# 1                       150.0               82.0     4     1.0  2 mois
# 3                         NaN               84.0     1     1.0     NaN
# 6                         NaN               75.0     1     1.0     NaN
# 8                         NaN                NaN   NaN     NaN     NaN
# ...                       ...                ...   ...     ...     ...
# 36588                     NaN              130.0     2     2.0     NaN
# 36590                     NaN               70.0     2     1.0  Aucune
# 36591                     NaN               86.0     3     1.0     NaN
# 36592                     NaN              128.0    7+     2.0     NaN
# 36597                     NaN                NaN   NaN     NaN     NaN
#
#       Âge du bien Horaire d'arrivée Horaire de départ
# 0             NaN               NaN               NaN
# 1             NaN               NaN               NaN
# 3            Neuf               NaN               NaN
# 6             NaN               NaN               NaN
# 8             NaN             14:00             12:00
# ...           ...               ...               ...
# 36588     1-5 ans               NaN               NaN
# 36590         NaN               NaN               NaN
# 36591        Neuf               NaN               NaN
# 36592        Neuf               NaN               NaN
# 36597         NaN             12:00             11:00
#
# [23307 rows x 13 columns]

# %%
df
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                             équipements non mentionnés
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  \
# 0                                 NaN               NaN
# 1               Appartements, à louer    Sala el Jadida
# 3              Appartements, à vendre  Quartier du Parc
# 6              Appartements, à vendre    Toute la ville
# 8      Locations de vacances, à louer            Guéliz
# ...                               ...               ...
# 36588          Appartements, à vendre          Harhoura
# 36590           Appartements, à louer        La Prairie
# 36591          Appartements, à vendre          Harhoura
# 36592          Appartements, à vendre           Mimosas
# 36597  Locations de vacances, à louer              Anza
#
#        Frais de syndic / mois  Surface habitable Étage  Salons Caution  \
# 0                         NaN                NaN   NaN     NaN     NaN
# 1                       150.0               82.0     4     1.0  2 mois
# 3                         NaN               84.0     1     1.0     NaN
# 6                         NaN               75.0     1     1.0     NaN
# 8                         NaN                NaN   NaN     NaN     NaN
# ...                       ...                ...   ...     ...     ...
# 36588                     NaN              130.0     2     2.0     NaN
# 36590                     NaN               70.0     2     1.0  Aucune
# 36591                     NaN               86.0     3     1.0     NaN
# 36592                     NaN              128.0    7+     2.0     NaN
# 36597                     NaN                NaN   NaN     NaN     NaN
#
#       Âge du bien Horaire d'arrivée Horaire de départ
# 0             NaN               NaN               NaN
# 1             NaN               NaN               NaN
# 3            Neuf               NaN               NaN
# 6             NaN               NaN               NaN
# 8             NaN             14:00             12:00
# ...           ...               ...               ...
# 36588     1-5 ans               NaN               NaN
# 36590         NaN               NaN               NaN
# 36591        Neuf               NaN               NaN
# 36592        Neuf               NaN               NaN
# 36597         NaN             12:00             11:00
#
# [23307 rows x 13 columns]

# %%
df.isnull().sum ()
# Out:
# House Name                    0
# Prix                       1920
# Équipements                   0
# Type                          1
# Secteur                     101
# Frais de syndic / mois    20502
# Surface habitable         11046
# Étage                     10776
# Salons                    10908
# Caution                   18762
# Âge du bien               17739
# Horaire d'arrivée         14035
# Horaire de départ         14135
# dtype: int64

# %%
import pandas as pd
import numpy as np



# the values to replace with NaN
valeurs_recherchees = ['équipements non mentionnés']

# Use a boolean filter to identify the cells to replace with NaN
filtre = df['Équipements'].isin(valeurs_recherchees)

# Replace the specified values with NaN
df.loc[filtre, 'Équipements'] = np.nan

print("DataFrame original:")
print(df)
# Out:
# DataFrame original:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  \
# 0                                 NaN               NaN
# 1               Appartements, à louer    Sala el Jadida
# 3              Appartements, à vendre  Quartier du Parc
# 6              Appartements, à vendre    Toute la ville
# 8      Locations de vacances, à louer            Guéliz
# ...                               ...               ...
# 36588          Appartements, à vendre          Harhoura
# 36590           Appartements, à louer        La Prairie
# 36591          Appartements, à vendre          Harhoura
# 36592          Appartements, à vendre           Mimosas
# 36597  Locations de vacances, à louer              Anza
#
#        Frais de syndic / mois  Surface habitable Étage  Salons Caution  \
# 0                         NaN                NaN   NaN     NaN     NaN
# 1                       150.0               82.0     4     1.0  2 mois
# 3                         NaN               84.0     1     1.0     NaN
# 6                         NaN               75.0     1     1.0     NaN
# 8                         NaN                NaN   NaN     NaN     NaN
# ...                       ...                ...   ...     ...     ...
# 36588                     NaN              130.0     2     2.0     NaN
# 36590                     NaN               70.0     2     1.0  Aucune
# 36591                     NaN               86.0     3     1.0     NaN
# 36592                     NaN              128.0    7+     2.0     NaN
# 36597                     NaN                NaN   NaN     NaN     NaN
#
#       Âge du bien Horaire d'arrivée Horaire de départ
# 0             NaN               NaN               NaN
# 1             NaN               NaN               NaN
# 3            Neuf               NaN               NaN
# 6             NaN               NaN               NaN
# 8             NaN             14:00             12:00
# ...           ...               ...               ...
# 36588     1-5 ans               NaN               NaN
# 36590         NaN               NaN               NaN
# 36591        Neuf               NaN               NaN
# 36592        Neuf               NaN               NaN
# 36597         NaN             12:00             11:00
#
# [23307 rows x 13 columns]

# %%
df.isnull().sum ()
# Out:
# House Name                    0
# Prix                       1920
# Équipements                  75
# Type                          1
# Secteur                     101
# Frais de syndic / mois    20502
# Surface habitable         11046
# Étage                     10776
# Salons                    10908
# Caution                   18762
# Âge du bien               17739
# Horaire d'arrivée         14035
# Horaire de départ         14135
# dtype: int64

# %%
import pandas as pd
import numpy as np



# Specify the values you want to replace with NaN
valeurs_recherchees = ['Aucune']

# Use a boolean filter to identify the cells to replace with NaN
filtre = df['Caution'].isin(valeurs_recherchees)

# Replace the specified values with NaN
df.loc[filtre, 'Caution'] = np.nan

print("DataFrame original:")
print(df)
# Out:
# DataFrame original:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  \
# 0                                 NaN               NaN
# 1               Appartements, à louer    Sala el Jadida
# 3              Appartements, à vendre  Quartier du Parc
# 6              Appartements, à vendre    Toute la ville
# 8      Locations de vacances, à louer            Guéliz
# ...                               ...               ...
# 36588          Appartements, à vendre          Harhoura
# 36590           Appartements, à louer        La Prairie
# 36591          Appartements, à vendre          Harhoura
# 36592          Appartements, à vendre           Mimosas
# 36597  Locations de vacances, à louer              Anza
#
#        Frais de syndic / mois  Surface habitable Étage  Salons Caution  \
# 0                         NaN                NaN   NaN     NaN     NaN
# 1                       150.0               82.0     4     1.0  2 mois
# 3                         NaN               84.0     1     1.0     NaN
# 6                         NaN               75.0     1     1.0     NaN
# 8                         NaN                NaN   NaN     NaN     NaN
# ...                       ...                ...   ...     ...     ...
# 36588                     NaN              130.0     2     2.0     NaN
# 36590                     NaN               70.0     2     1.0     NaN
# 36591                     NaN               86.0     3     1.0     NaN
# 36592                     NaN              128.0    7+     2.0     NaN
# 36597                     NaN                NaN   NaN     NaN     NaN
#
#       Âge du bien Horaire d'arrivée Horaire de départ
# 0             NaN               NaN               NaN
# 1             NaN               NaN               NaN
# 3            Neuf               NaN               NaN
# 6             NaN               NaN               NaN
# 8             NaN             14:00             12:00
# ...           ...               ...               ...
# 36588     1-5 ans               NaN               NaN
# 36590         NaN               NaN               NaN
# 36591        Neuf               NaN               NaN
# 36592        Neuf               NaN               NaN
# 36597         NaN             12:00             11:00
#
# [23307 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# House Name                    0
# Prix                       1920
# Équipements                  75
# Type                          1
# Secteur                     101
# Frais de syndic / mois    20502
# Surface habitable         11046
# Étage                     10776
# Salons                    10908
# Caution                   19431
# Âge du bien               17739
# Horaire d'arrivée         14035
# Horaire de départ         14135
# dtype: int64

# %%
df.shape
# Out:
# (23307, 13)

# %%
avito_data.shape
# Out:
# (23307, 13)

# %%
import missingno as msno
msno.bar(avito_data)
# Out:
# <Axes: >

# %% [markdown]
# we see that there are 3 columns that have many null values and with the smallest knowledge in the metier they don't impact to the price of the house
# so I decide to delete them

# %%
df=avito_data.drop(['Âge du bien','Caution','Frais de syndic / mois'],axis=1)
df.isnull().sum()
# Out:
# House Name               0
# Prix                  1920
# Équipements             75
# Type                     1
# Secteur                101
# Surface habitable    11046
# Étage                10776
# Salons               10908
# Horaire d'arrivée    14035
# Horaire de départ    14135
# dtype: int64

# %%
avito_data = df

# %%
import missingno as msno
msno.bar(avito_data)
# Out:
# <Axes: >

# %%
# Counting words in each cell of the 'equipment' column (separated by commas) and storing the result in 'equipments_nbr'
avito_data['equipments_nbr'] = avito_data['Équipements'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)

# Display the DataFrame with the new column
print(avito_data)
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  Surface habitable  \
# 0                                 NaN               NaN                NaN
# 1               Appartements, à louer    Sala el Jadida               82.0
# 3              Appartements, à vendre  Quartier du Parc               84.0
# 6              Appartements, à vendre    Toute la ville               75.0
# 8      Locations de vacances, à louer            Guéliz                NaN
# ...                               ...               ...                ...
# 36588          Appartements, à vendre          Harhoura              130.0
# 36590           Appartements, à louer        La Prairie               70.0
# 36591          Appartements, à vendre          Harhoura               86.0
# 36592          Appartements, à vendre           Mimosas              128.0
# 36597  Locations de vacances, à louer              Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 3         1     1.0               NaN               NaN               6
# 6         1     1.0               NaN               NaN               2
# 8       NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36588     2     2.0               NaN               NaN               9
# 36590     2     1.0               NaN               NaN              10
# 36591     3     1.0               NaN               NaN               6
# 36592    7+     2.0               NaN               NaN               7
# 36597   NaN     NaN             12:00             11:00              11
#
# [23307 rows x 11 columns]

# %%
avito_data
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  Surface habitable  \
# 0                                 NaN               NaN                NaN
# 1               Appartements, à louer    Sala el Jadida               82.0
# 3              Appartements, à vendre  Quartier du Parc               84.0
# 6              Appartements, à vendre    Toute la ville               75.0
# 8      Locations de vacances, à louer            Guéliz                NaN
# ...                               ...               ...                ...
# 36588          Appartements, à vendre          Harhoura              130.0
# 36590           Appartements, à louer        La Prairie               70.0
# 36591          Appartements, à vendre          Harhoura               86.0
# 36592          Appartements, à vendre           Mimosas              128.0
# 36597  Locations de vacances, à louer              Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 3         1     1.0               NaN               NaN               6
# 6         1     1.0               NaN               NaN               2
# 8       NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36588     2     2.0               NaN               NaN               9
# 36590     2     1.0               NaN               NaN              10
# 36591     3     1.0               NaN               NaN               6
# 36592    7+     2.0               NaN               NaN               7
# 36597   NaN     NaN             12:00             11:00              11
#
# [23307 rows x 11 columns]

# %%
occurrences = avito_data['Type'].value_counts()
occurrences
# Out:
# Locations de vacances, à louer       10775
# Appartements, à louer                 6302
# Appartements, à vendre                6203
# Appartements, demande de location       24
# Colocations, à louer                     2
# Name: Type, dtype: int64

# %%
# Utilisez la méthode drop pour supprimer les lignes contenant la valeur spécifiée
df1 = df[df['Type'] != 'Appartements, demande de location']


df1
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  Surface habitable  \
# 0                                 NaN               NaN                NaN
# 1               Appartements, à louer    Sala el Jadida               82.0
# 3              Appartements, à vendre  Quartier du Parc               84.0
# 6              Appartements, à vendre    Toute la ville               75.0
# 8      Locations de vacances, à louer            Guéliz                NaN
# ...                               ...               ...                ...
# 36588          Appartements, à vendre          Harhoura              130.0
# 36590           Appartements, à louer        La Prairie               70.0
# 36591          Appartements, à vendre          Harhoura               86.0
# 36592          Appartements, à vendre           Mimosas              128.0
# 36597  Locations de vacances, à louer              Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 3         1     1.0               NaN               NaN               6
# 6         1     1.0               NaN               NaN               2
# 8       NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36588     2     2.0               NaN               NaN               9
# 36590     2     1.0               NaN               NaN              10
# 36591     3     1.0               NaN               NaN               6
# 36592    7+     2.0               NaN               NaN               7
# 36597   NaN     NaN             12:00             11:00              11
#
# [23283 rows x 11 columns]

# %%
df1['Type'].unique()
# Out:
# array([nan, 'Appartements, à louer', 'Appartements, à vendre',
#        'Locations de vacances, à louer', 'Colocations, à louer'],
#       dtype=object)

# %%
# Utilisez la méthode drop pour supprimer les lignes contenant la valeur spécifiée
df2 = df1[df1['Type'] != 'Colocations, à louer']


df2
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  Surface habitable  \
# 0                                 NaN               NaN                NaN
# 1               Appartements, à louer    Sala el Jadida               82.0
# 3              Appartements, à vendre  Quartier du Parc               84.0
# 6              Appartements, à vendre    Toute la ville               75.0
# 8      Locations de vacances, à louer            Guéliz                NaN
# ...                               ...               ...                ...
# 36588          Appartements, à vendre          Harhoura              130.0
# 36590           Appartements, à louer        La Prairie               70.0
# 36591          Appartements, à vendre          Harhoura               86.0
# 36592          Appartements, à vendre           Mimosas              128.0
# 36597  Locations de vacances, à louer              Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 3         1     1.0               NaN               NaN               6
# 6         1     1.0               NaN               NaN               2
# 8       NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36588     2     2.0               NaN               NaN               9
# 36590     2     1.0               NaN               NaN              10
# 36591     3     1.0               NaN               NaN               6
# 36592    7+     2.0               NaN               NaN               7
# 36597   NaN     NaN             12:00             11:00              11
#
# [23281 rows x 11 columns]

# %%
d=df2['Type'].value_counts()
d
# Out:
# Locations de vacances, à louer    10775
# Appartements, à louer              6302
# Appartements, à vendre             6203
# Name: Type, dtype: int64

# %%
df2
# Out:
#                                               House Name          Prix  \
# 0                                   House Name Not Found           NaN
# 1                            appartement meublé à louer       5 000 DH
# 3                Appartement à vendre 84 m² à Mohammedia  1 300 000 DH
# 6                    Appartement à vendre 75 m² à Saidia    490 000 DH
# 8                        appart calme à centre de ville   250 DH /Nuit
# ...                                                  ...           ...
# 36588  Appartement de 3 chambres en location à harhoura       6 500 DH
# 36590          appartements de Lux en location à ifrane         300 DH
# 36591             Appartement à vendre 86 m² à harhoura   1 100 000 DH
# 36592   APPARTEMENT DE 136 M2 SUR LE BOULEVARD MOHAMED 5    890 000 DH
# 36597         App meublé avec wifi et ascenseur à agadir  300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 3      Ascenseur, Balcon, Meublé, Terrasse, Climatisa...
# 6                                       Terrasse, Balcon
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# ...                                                  ...
# 36588  Sécurité, Cuisine équipée, Climatisation, Conc...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36591  Balcon, Cuisine équipée, Climatisation, Concie...
# 36592  Ascenseur, Cuisine équipée, Concierge, Parking...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type           Secteur  Surface habitable  \
# 0                                 NaN               NaN                NaN
# 1               Appartements, à louer    Sala el Jadida               82.0
# 3              Appartements, à vendre  Quartier du Parc               84.0
# 6              Appartements, à vendre    Toute la ville               75.0
# 8      Locations de vacances, à louer            Guéliz                NaN
# ...                               ...               ...                ...
# 36588          Appartements, à vendre          Harhoura              130.0
# 36590           Appartements, à louer        La Prairie               70.0
# 36591          Appartements, à vendre          Harhoura               86.0
# 36592          Appartements, à vendre           Mimosas              128.0
# 36597  Locations de vacances, à louer              Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 3         1     1.0               NaN               NaN               6
# 6         1     1.0               NaN               NaN               2
# 8       NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36588     2     2.0               NaN               NaN               9
# 36590     2     1.0               NaN               NaN              10
# 36591     3     1.0               NaN               NaN               6
# 36592    7+     2.0               NaN               NaN               7
# 36597   NaN     NaN             12:00             11:00              11
#
# [23281 rows x 11 columns]

# %%
 # Remplacez "votre_fichier.csv" par le nom de votre fichier

# Supprimer les lignes avec la valeur spécifiée dans la colonne "Type"
df2 = df2[df2['Type'] != 'Appartements, à vendre']

# %%
df2
# Out:
#                                         House Name            Prix  \
# 0                             House Name Not Found             NaN
# 1                      appartement meublé à louer         5 000 DH
# 8                  appart calme à centre de ville     250 DH /Nuit
# 11                appart à louer pour les famille     250 DH /Nuit
# 12                appart calme à coter de la gare     250 DH /Nuit
# ...                                            ...             ...
# 36584           Appartement à louer 60 m² à Tanger        4 300 DH
# 36586  Magnifique appartement vue sur mer à mehdia  1 400 DH /Nuit
# 36587           Belle appartement au centre ville     250 DH /Nuit
# 36590    appartements de Lux en location à ifrane           300 DH
# 36597   App meublé avec wifi et ascenseur à agadir    300 DH /Nuit
#
#                                              Équipements  \
# 0                                                    NaN
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 0                                 NaN             NaN                NaN
# 1               Appartements, à louer  Sala el Jadida               82.0
# 8      Locations de vacances, à louer          Guéliz                NaN
# 11     Locations de vacances, à louer          Guéliz                NaN
# 12     Locations de vacances, à louer          Guéliz                NaN
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf               60.0
# 36586  Locations de vacances, à louer   Autre secteur                NaN
# 36587  Locations de vacances, à louer           Agdal                NaN
# 36590           Appartements, à louer      La Prairie               70.0
# 36597  Locations de vacances, à louer            Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 0       NaN     NaN               NaN               NaN               0
# 1         4     1.0               NaN               NaN               5
# 8       NaN     NaN             14:00             12:00              12
# 11      NaN     NaN             14:00             12:00              12
# 12      NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36584     5     1.0               NaN               NaN               8
# 36586   NaN     NaN             14:00             12:00              12
# 36587   NaN     NaN             12:30             12:00              12
# 36590     2     1.0               NaN               NaN              10
# 36597   NaN     NaN             12:00             11:00              11
#
# [17078 rows x 11 columns]

# %%
d=df2['Type'].value_counts()
d
# Out:
# Locations de vacances, à louer    10775
# Appartements, à louer              6302
# Name: Type, dtype: int64

# %%
df2 = df2.dropna(subset=['Type','Équipements','Secteur'])

# %%
df2.isnull().sum()
# Out:
# House Name               0
# Prix                  1099
# Équipements              0
# Type                     0
# Secteur                  0
# Surface habitable    11013
# Étage                10747
# Salons               10747
# Horaire d'arrivée     7765
# Horaire de départ     7865
# equipments_nbr           0
# dtype: int64

# %%
df3 = pd.DataFrame(df2)

# Affichez le DataFrame original
print("DataFrame original:")
print(df3)

# Filtrez les lignes où la valeur dans la colonne 'Prix' est nulle
df_null_prix = df3[df3['Prix'].isnull()]

# Affichez les lignes où la valeur dans la colonne 'Prix' est nulle
print("\nLignes où la valeur dans la colonne 'Prix' est nulle:")
print(df_null_prix)

# Supprimez les lignes où la valeur dans la colonne 'Prix' est nulle du DataFrame d'origine
df4 = df3.dropna(subset=['Prix'])

# Affichez le DataFrame après la suppression
print("\nDataFrame après la suppression des lignes où la valeur dans la colonne 'Prix' est nulle:")
print(df3)

# Créez un autre DataFrame avec les lignes où la valeur dans la colonne 'Prix' est nulle
df_null_prix_separe = pd.DataFrame(df_null_prix)

df_null_prix_separe.to_csv('valeurs_nulles_prix.csv', index=False)
# Out:
# DataFrame original:
#                                         House Name            Prix  \
# 1                      appartement meublé à louer         5 000 DH
# 8                  appart calme à centre de ville     250 DH /Nuit
# 11                appart à louer pour les famille     250 DH /Nuit
# 12                appart calme à coter de la gare     250 DH /Nuit
# 13                   appart à coter de carre eden     250 DH /Nuit
# ...                                            ...             ...
# 36584           Appartement à louer 60 m² à Tanger        4 300 DH
# 36586  Magnifique appartement vue sur mer à mehdia  1 400 DH /Nuit
# 36587           Belle appartement au centre ville     250 DH /Nuit
# 36590    appartements de Lux en location à ifrane           300 DH
# 36597   App meublé avec wifi et ascenseur à agadir    300 DH /Nuit
#
#                                              Équipements  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 1               Appartements, à louer  Sala el Jadida               82.0
# 8      Locations de vacances, à louer          Guéliz                NaN
# 11     Locations de vacances, à louer          Guéliz                NaN
# 12     Locations de vacances, à louer          Guéliz                NaN
# 13     Locations de vacances, à louer          Guéliz                NaN
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf               60.0
# 36586  Locations de vacances, à louer   Autre secteur                NaN
# 36587  Locations de vacances, à louer           Agdal                NaN
# 36590           Appartements, à louer      La Prairie               70.0
# 36597  Locations de vacances, à louer            Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 1         4     1.0               NaN               NaN               5
# 8       NaN     NaN             14:00             12:00              12
# 11      NaN     NaN             14:00             12:00              12
# 12      NaN     NaN             14:00             12:00              12
# 13      NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36584     5     1.0               NaN               NaN               8
# 36586   NaN     NaN             14:00             12:00              12
# 36587   NaN     NaN             12:30             12:00              12
# 36590     2     1.0               NaN               NaN              10
# 36597   NaN     NaN             12:00             11:00              11
#
# [17022 rows x 11 columns]
#
# Lignes où la valeur dans la colonne 'Prix' est nulle:
#                                               House Name Prix  \
# 5507                          Appartement 150 m² à Rabat  NaN
# 5536                          Appartement 150 m² à Rabat  NaN
# 5565                          Appartement 150 m² à Rabat  NaN
# 5594                          Appartement 150 m² à Rabat  NaN
# 5623                          Appartement 150 m² à Rabat  NaN
# ...                                                  ...  ...
# 36513  Magnifique appartement meublé immeuble vue sur...  NaN
# 36540            jolie appartements à louer à la MARINA   NaN
# 36544  Magnifique appartement meublé immeuble vue sur...  NaN
# 36571            jolie appartements à louer à la MARINA   NaN
# 36575  Magnifique appartement meublé immeuble vue sur...  NaN
#
#                                              Équipements  \
# 5507   Concierge, Chauffage, Parking, Cuisine équipée...
# 5536   Ascenseur, Concierge, Parking, Cuisine équipée...
# 5565   Sécurité, Concierge, Chauffage, Terrasse, Clim...
# 5594   Cuisine équipée, Parking, Balcon, Sécurité, Te...
# 5623   Parking, Sécurité, Concierge, Terrasse, Cuisin...
# ...                                                  ...
# 36513  Fer à repasser, Sécurité, Climatisation, Cuisi...
# 36540  Meublé, Concierge, Sécurité, Chauffage, Parkin...
# 36544  Cuisine équipée, Parking, Climatisation, Artic...
# 36571  Balcon, Sécurité, Cuisine équipée, Chauffage, ...
# 36575  Cuisine équipée, Articles de toilettage, Télév...
#
#                                  Type        Secteur  Surface habitable Étage  \
# 5507            Appartements, à louer       Hay Riad              150.0     4
# 5536            Appartements, à louer       Hay Riad              150.0     4
# 5565            Appartements, à louer       Hay Riad              150.0     4
# 5594            Appartements, à louer       Hay Riad              150.0     4
# 5623            Appartements, à louer       Hay Riad              150.0     4
# ...                               ...            ...                ...   ...
# 36513  Locations de vacances, à louer  Autre secteur                NaN   NaN
# 36540           Appartements, à louer         Marina              101.0     1
# 36544  Locations de vacances, à louer  Autre secteur                NaN   NaN
# 36571           Appartements, à louer         Marina              101.0     1
# 36575  Locations de vacances, à louer  Autre secteur                NaN   NaN
#
#        Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 5507      2.0               NaN               NaN               9
# 5536      2.0               NaN               NaN               9
# 5565      2.0               NaN               NaN               9
# 5594      2.0               NaN               NaN               9
# 5623      2.0               NaN               NaN               9
# ...       ...               ...               ...             ...
# 36513     NaN             13:30             11:00              13
# 36540     1.0               NaN               NaN               8
# 36544     NaN             13:30             11:00              13
# 36571     1.0               NaN               NaN               8
# 36575     NaN             13:30             11:00              13
#
# [1099 rows x 11 columns]
#
# DataFrame après la suppression des lignes où la valeur dans la colonne 'Prix' est nulle:
#                                         House Name            Prix  \
# 1                      appartement meublé à louer         5 000 DH
# 8                  appart calme à centre de ville     250 DH /Nuit
# 11                appart à louer pour les famille     250 DH /Nuit
# 12                appart calme à coter de la gare     250 DH /Nuit
# 13                   appart à coter de carre eden     250 DH /Nuit
# ...                                            ...             ...
# 36584           Appartement à louer 60 m² à Tanger        4 300 DH
# 36586  Magnifique appartement vue sur mer à mehdia  1 400 DH /Nuit
# 36587           Belle appartement au centre ville     250 DH /Nuit
# 36590    appartements de Lux en location à ifrane           300 DH
# 36597   App meublé avec wifi et ascenseur à agadir    300 DH /Nuit
#
#                                              Équipements  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 1               Appartements, à louer  Sala el Jadida               82.0
# 8      Locations de vacances, à louer          Guéliz                NaN
# 11     Locations de vacances, à louer          Guéliz                NaN
# 12     Locations de vacances, à louer          Guéliz                NaN
# 13     Locations de vacances, à louer          Guéliz                NaN
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf               60.0
# 36586  Locations de vacances, à louer   Autre secteur                NaN
# 36587  Locations de vacances, à louer           Agdal                NaN
# 36590           Appartements, à louer      La Prairie               70.0
# 36597  Locations de vacances, à louer            Anza                NaN
#
#       Étage  Salons Horaire d'arrivée Horaire de départ  equipments_nbr
# 1         4     1.0               NaN               NaN               5
# 8       NaN     NaN             14:00             12:00              12
# 11      NaN     NaN             14:00             12:00              12
# 12      NaN     NaN             14:00             12:00              12
# 13      NaN     NaN             14:00             12:00              12
# ...     ...     ...               ...               ...             ...
# 36584     5     1.0               NaN               NaN               8
# 36586   NaN     NaN             14:00             12:00              12
# 36587   NaN     NaN             12:30             12:00              12
# 36590     2     1.0               NaN               NaN              10
# 36597   NaN     NaN             12:00             11:00              11
#
# [17022 rows x 11 columns]

# %%
df3.isnull().sum()
# Out:
# House Name               0
# Prix                  1099
# Équipements              0
# Type                     0
# Secteur                  0
# Surface habitable    11013
# Étage                10747
# Salons               10747
# Horaire d'arrivée     7765
# Horaire de départ     7865
# equipments_nbr           0
# dtype: int64

# %%
df4 = df3

# %%
occurrences1 = df4['Type'].value_counts()
occurrences1
# Out:
# Locations de vacances, à louer    10747
# Appartements, à louer              6275
# Name: Type, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assurez-vous que votre DataFrame 'd' existe et contient les colonnes 'Surface habitable' et 'Prix'

# Visualize the relationship between 'Surface habitable' and 'Prix' using a scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Surface habitable', y='Prix', data=df4)
plt.title('Scatter Plot for Surface habitable vs Prix in Avito Dataset')
plt.show()

# %%
from sklearn.impute import SimpleImputer
mean_imputer = SimpleImputer(strategy='mean')
df4['Surface habitable'] = mean_imputer.fit_transform(df4[['Surface habitable']])

# %%
df4.isnull().sum()
# Out:
# House Name              0
# Prix                 1099
# Équipements             0
# Type                    0
# Secteur                 0
# Surface habitable       0
# Étage                   0
# Salons                  0
# Horaire d'arrivée    7765
# Horaire de départ    7865
# equipments_nbr          0
# dtype: int64

# %%
df4.dtypes
# Out:
# House Name            object
# Prix                  object
# Équipements           object
# Type                  object
# Secteur               object
# Surface habitable    float64
# Étage                float64
# Salons               float64
# Horaire d'arrivée     object
# Horaire de départ     object
# equipments_nbr         int64
# dtype: object

# %%
occurrences1 = df4['Étage'].value_counts()
occurrences1
# Out:
# 2.0    12276
# 3.0     1338
# 4.0     1051
# 1.0     1050
# 0.0      744
# 5.0      265
# 6.0      198
# 7.0      100
# Name: Étage, dtype: int64

# %%
df4.loc[df4['Étage'] == 'Rezdechaussée','Étage']=0

# %%
df4['Étage'] = pd.to_numeric(df4['Étage'], errors='coerce').fillna(-1).astype(int)

# %%
df4['Étage']=df4['Étage'].astype(int)

# %%
df4['Étage'] = df4['Étage'].replace(-1, float('nan'))

# %%
df4['Étage'] = df4['Étage'].fillna(df4['Étage'].mode()[0])

# %%
df4['Salons'] = df4['Salons'].fillna(df4['Salons'].mode()[0])

# %%
df4.isnull().sum()
# Out:
# House Name              0
# Prix                 1099
# Équipements             0
# Type                    0
# Secteur                 0
# Surface habitable       0
# Étage                   0
# Salons                  0
# Horaire d'arrivée    7765
# Horaire de départ    7865
# equipments_nbr          0
# dtype: int64

# %%
df4=df4.drop(['Horaire d\'arrivée','Horaire de départ'],axis=1)
df4.isnull().sum()
# Out:
# House Name              0
# Prix                 1099
# Équipements             0
# Type                    0
# Secteur                 0
# Surface habitable       0
# Étage                   0
# Salons                  0
# equipments_nbr          0
# dtype: int64

# %%
# Sélectionner les lignes avec des valeurs nulles dans la colonne "Prix"
df_null_prix = df4[df4['Prix'].isnull()]

# Enregistrer le DataFrame contenant les valeurs nulles dans un nouveau fichier
df_null_prix.to_csv("valeurs_nulles_prix.csv", index=False)  # Remplacez "valeurs_nulles_prix.csv" par le nom souhaité pour le nouveau fichier

# Supprimer les lignes avec des valeurs nulles dans la colonne "Prix" du DataFrame d'origine
df4 = df4.dropna(subset=['Prix'])

# Enregistrer le DataFrame modifié dans un nouveau fichier (si nécessaire)
df.to_csv("nouveau_fichier_sans_nulles.csv", index=False)  # Remplacez "nouveau_fichier_sans_nulles.csv" par le nom souhaité pour le nouveau fichier

# %%
df4.isnull().sum()
# Out:
# House Name           0
# Prix                 0
# Équipements          0
# Type                 0
# Secteur              0
# Surface habitable    0
# Étage                0
# Salons               0
# equipments_nbr       0
# dtype: int64

# %%
df4
# Out:
#                                         House Name            Prix  \
# 1                      appartement meublé à louer         5 000 DH
# 8                  appart calme à centre de ville     250 DH /Nuit
# 11                appart à louer pour les famille     250 DH /Nuit
# 12                appart calme à coter de la gare     250 DH /Nuit
# 13                   appart à coter de carre eden     250 DH /Nuit
# ...                                            ...             ...
# 36584           Appartement à louer 60 m² à Tanger        4 300 DH
# 36586  Magnifique appartement vue sur mer à mehdia  1 400 DH /Nuit
# 36587           Belle appartement au centre ville     250 DH /Nuit
# 36590    appartements de Lux en location à ifrane           300 DH
# 36597   App meublé avec wifi et ascenseur à agadir    300 DH /Nuit
#
#                                              Équipements  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 1               Appartements, à louer  Sala el Jadida          82.000000
# 8      Locations de vacances, à louer          Guéliz          88.519221
# 11     Locations de vacances, à louer          Guéliz          88.519221
# 12     Locations de vacances, à louer          Guéliz          88.519221
# 13     Locations de vacances, à louer          Guéliz          88.519221
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf          60.000000
# 36586  Locations de vacances, à louer   Autre secteur          88.519221
# 36587  Locations de vacances, à louer           Agdal          88.519221
# 36590           Appartements, à louer      La Prairie          70.000000
# 36597  Locations de vacances, à louer            Anza          88.519221
#
#        Étage  Salons  equipments_nbr
# 1          4     1.0               5
# 8          2     1.0              12
# 11         2     1.0              12
# 12         2     1.0              12
# 13         2     1.0              12
# ...      ...     ...             ...
# 36584      5     1.0               8
# 36586      2     1.0              12
# 36587      2     1.0              12
# 36590      2     1.0              10
# 36597      2     1.0              11
#
# [15923 rows x 9 columns]

# %%
df4['Prix'] = df4['Prix'].str.replace('DH /Nuit', '').str.replace(' ', '').str.replace(' ','')

# %%
df4['Prix'] = df4['Prix'].str.replace('DH', '').str.replace(' ', '').str.replace(' ','')

# %%
df4['Prix']=df4['Prix'].astype(int)

# %%
df4.dtypes
# Out:
# House Name            object
# Prix                   int64
# Équipements           object
# Type                  object
# Secteur               object
# Surface habitable    float64
# Étage                  int64
# Salons               float64
# equipments_nbr         int64
# dtype: object

# %%
df4
# Out:
#                                         House Name  Prix  \
# 1                      appartement meublé à louer   5000
# 8                  appart calme à centre de ville    250
# 11                appart à louer pour les famille    250
# 12                appart calme à coter de la gare    250
# 13                   appart à coter de carre eden    250
# ...                                            ...   ...
# 36584           Appartement à louer 60 m² à Tanger  4300
# 36586  Magnifique appartement vue sur mer à mehdia  1400
# 36587           Belle appartement au centre ville    250
# 36590    appartements de Lux en location à ifrane    300
# 36597   App meublé avec wifi et ascenseur à agadir   300
#
#                                              Équipements  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 1               Appartements, à louer  Sala el Jadida          82.000000
# 8      Locations de vacances, à louer          Guéliz          88.519221
# 11     Locations de vacances, à louer          Guéliz          88.519221
# 12     Locations de vacances, à louer          Guéliz          88.519221
# 13     Locations de vacances, à louer          Guéliz          88.519221
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf          60.000000
# 36586  Locations de vacances, à louer   Autre secteur          88.519221
# 36587  Locations de vacances, à louer           Agdal          88.519221
# 36590           Appartements, à louer      La Prairie          70.000000
# 36597  Locations de vacances, à louer            Anza          88.519221
#
#        Étage  Salons  equipments_nbr
# 1          4     1.0               5
# 8          2     1.0              12
# 11         2     1.0              12
# 12         2     1.0              12
# 13         2     1.0              12
# ...      ...     ...             ...
# 36584      5     1.0               8
# 36586      2     1.0              12
# 36587      2     1.0              12
# 36590      2     1.0              10
# 36597      2     1.0              11
#
# [15923 rows x 9 columns]

# %%
# Liste des valeurs à supprimer dans la colonne "Secteur"
valeurs_a_supprimer = [
    'Mabrouka',
    'Hassan',
    'Hay Dakhla',
    'Nahda-1',
    'Riad Oulad Mtaa',
    'Cité Adrar',
    'Hay El Qods',
    'Palmier',
    'Route de Casablanca',
    'Hay Izdihar',
    'Aïn Sebaâ',
    'Quartier des Hôpitaux'
]

# Supprimer les lignes avec les valeurs spécifiées dans la colonne "Secteur"
df4 = df4[~df4['Secteur'].isin(valeurs_a_supprimer)]

# %%
df4
# Out:
#                                         House Name  Prix  \
# 1                      appartement meublé à louer   5000
# 8                  appart calme à centre de ville    250
# 11                appart à louer pour les famille    250
# 12                appart calme à coter de la gare    250
# 13                   appart à coter de carre eden    250
# ...                                            ...   ...
# 36584           Appartement à louer 60 m² à Tanger  4300
# 36586  Magnifique appartement vue sur mer à mehdia  1400
# 36587           Belle appartement au centre ville    250
# 36590    appartements de Lux en location à ifrane    300
# 36597   App meublé avec wifi et ascenseur à agadir   300
#
#                                              Équipements  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...
# 11     Piscine, Meublé, Climatisation, Télévision, WI...
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...
# ...                                                  ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...
#
#                                  Type         Secteur  Surface habitable  \
# 1               Appartements, à louer  Sala el Jadida          82.000000
# 8      Locations de vacances, à louer          Guéliz          88.519221
# 11     Locations de vacances, à louer          Guéliz          88.519221
# 12     Locations de vacances, à louer          Guéliz          88.519221
# 13     Locations de vacances, à louer          Guéliz          88.519221
# ...                               ...             ...                ...
# 36584           Appartements, à louer         Du Golf          60.000000
# 36586  Locations de vacances, à louer   Autre secteur          88.519221
# 36587  Locations de vacances, à louer           Agdal          88.519221
# 36590           Appartements, à louer      La Prairie          70.000000
# 36597  Locations de vacances, à louer            Anza          88.519221
#
#        Étage  Salons  equipments_nbr
# 1          4     1.0               5
# 8          2     1.0              12
# 11         2     1.0              12
# 12         2     1.0              12
# 13         2     1.0              12
# ...      ...     ...             ...
# 36584      5     1.0               8
# 36586      2     1.0              12
# 36587      2     1.0              12
# 36590      2     1.0              10
# 36597      2     1.0              11
#
# [15784 rows x 9 columns]

# %% [markdown]
# # **Feature selection**

# %%
df5 =df4

# %%
import pandas as pd

# Assuming df is your DataFrame with a column named 'Type' containing two values

# Use pd.get_dummies to perform one-hot encoding
df5 = pd.get_dummies(df5, columns=['Type'], prefix='Type')

# Display the updated DataFrame
df5
# Out:
#                                         House Name  Prix  \
# 1                      appartement meublé à louer   5000
# 8                  appart calme à centre de ville    250
# 11                appart à louer pour les famille    250
# 12                appart calme à coter de la gare    250
# 13                   appart à coter de carre eden    250
# ...                                            ...   ...
# 36584           Appartement à louer 60 m² à Tanger  4300
# 36586  Magnifique appartement vue sur mer à mehdia  1400
# 36587           Belle appartement au centre ville    250
# 36590    appartements de Lux en location à ifrane    300
# 36597   App meublé avec wifi et ascenseur à agadir   300
#
#                                              Équipements         Secteur  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...  Sala el Jadida
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...          Guéliz
# 11     Piscine, Meublé, Climatisation, Télévision, WI...          Guéliz
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...          Guéliz
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...          Guéliz
# ...                                                  ...             ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...         Du Golf
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...   Autre secteur
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...           Agdal
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...      La Prairie
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...            Anza
#
#        Surface habitable  Étage  Salons  equipments_nbr  \
# 1              82.000000      4     1.0               5
# 8              88.519221      2     1.0              12
# 11             88.519221      2     1.0              12
# 12             88.519221      2     1.0              12
# 13             88.519221      2     1.0              12
# ...                  ...    ...     ...             ...
# 36584          60.000000      5     1.0               8
# 36586          88.519221      2     1.0              12
# 36587          88.519221      2     1.0              12
# 36590          70.000000      2     1.0              10
# 36597          88.519221      2     1.0              11
#
#        Type_Appartements, à louer  Type_Locations de vacances, à louer
# 1                               1                                    0
# 8                               0                                    1
# 11                              0                                    1
# 12                              0                                    1
# 13                              0                                    1
# ...                           ...                                  ...
# 36584                           1                                    0
# 36586                           0                                    1
# 36587                           0                                    1
# 36590                           1                                    0
# 36597                           0                                    1
#
# [15784 rows x 10 columns]

# %%
df6 = df5

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame with a column named 'OrdinalColumn'

# Create a LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to the 'OrdinalColumn'
df6['Secteur'] = label_encoder.fit_transform(df6['Secteur'])

# Display the updated DataFrame
df6
# Out:
#                                         House Name  Prix  \
# 1                      appartement meublé à louer   5000
# 8                  appart calme à centre de ville    250
# 11                appart à louer pour les famille    250
# 12                appart calme à coter de la gare    250
# 13                   appart à coter de carre eden    250
# ...                                            ...   ...
# 36584           Appartement à louer 60 m² à Tanger  4300
# 36586  Magnifique appartement vue sur mer à mehdia  1400
# 36587           Belle appartement au centre ville    250
# 36590    appartements de Lux en location à ifrane    300
# 36597   App meublé avec wifi et ascenseur à agadir   300
#
#                                              Équipements  Secteur  \
# 1      Sécurité, Parking, Ascenseur, Cuisine équipée,...       42
# 8      Serviettes, Meublé, Climatisation, Piscine, Pa...       20
# 11     Piscine, Meublé, Climatisation, Télévision, WI...       20
# 12     Ascenseur, Sécurité, Machine à laver, Cuisine ...       20
# 13     Climatisation, Sécurité, Parking, Meublé, Cuis...       20
# ...                                                  ...      ...
# 36584  Concierge, Balcon, Parking, Cuisine équipée, M...       17
# 36586  Chauffage, Sécurité, Parking, Meublé, Concierg...        6
# 36587  Meublé, Cuisine équipée, Machine à laver, Park...        1
# 36590  Concierge, Sécurité, Balcon, Chauffage, Ascens...       28
# 36597  Meublé, Parking, Serviettes, Télévision, Chauf...        5
#
#        Surface habitable  Étage  Salons  equipments_nbr  \
# 1              82.000000      4     1.0               5
# 8              88.519221      2     1.0              12
# 11             88.519221      2     1.0              12
# 12             88.519221      2     1.0              12
# 13             88.519221      2     1.0              12
# ...                  ...    ...     ...             ...
# 36584          60.000000      5     1.0               8
# 36586          88.519221      2     1.0              12
# 36587          88.519221      2     1.0              12
# 36590          70.000000      2     1.0              10
# 36597          88.519221      2     1.0              11
#
#        Type_Appartements, à louer  Type_Locations de vacances, à louer
# 1                               1                                    0
# 8                               0                                    1
# 11                              0                                    1
# 12                              0                                    1
# 13                              0                                    1
# ...                           ...                                  ...
# 36584                           1                                    0
# 36586                           0                                    1
# 36587                           0                                    1
# 36590                           1                                    0
# 36597                           0                                    1
#
# [15784 rows x 10 columns]

# %%
# Assuming df is your original DataFrame
selected_columns = ['House Name', 'Secteur','Surface habitable','Étage','Salons','equipments_nbr','Type_Appartements, à louer','Type_Locations de vacances, à louer','Prix']
new_df = df6[selected_columns].copy()

# Display the new DataFrame
new_df
# Out:
#                                         House Name  Secteur  \
# 1                      appartement meublé à louer        42
# 8                  appart calme à centre de ville        20
# 11                appart à louer pour les famille        20
# 12                appart calme à coter de la gare        20
# 13                   appart à coter de carre eden        20
# ...                                            ...      ...
# 36584           Appartement à louer 60 m² à Tanger       17
# 36586  Magnifique appartement vue sur mer à mehdia        6
# 36587           Belle appartement au centre ville         1
# 36590    appartements de Lux en location à ifrane        28
# 36597   App meublé avec wifi et ascenseur à agadir        5
#
#        Surface habitable  Étage  Salons  equipments_nbr  \
# 1              82.000000      4     1.0               5
# 8              88.519221      2     1.0              12
# 11             88.519221      2     1.0              12
# 12             88.519221      2     1.0              12
# 13             88.519221      2     1.0              12
# ...                  ...    ...     ...             ...
# 36584          60.000000      5     1.0               8
# 36586          88.519221      2     1.0              12
# 36587          88.519221      2     1.0              12
# 36590          70.000000      2     1.0              10
# 36597          88.519221      2     1.0              11
#
#        Type_Appartements, à louer  Type_Locations de vacances, à louer  Prix
# 1                               1                                    0  5000
# 8                               0                                    1   250
# 11                              0                                    1   250
# 12                              0                                    1   250
# 13                              0                                    1   250
# ...                           ...                                  ...   ...
# 36584                           1                                    0  4300
# 36586                           0                                    1  1400
# 36587                           0                                    1   250
# 36590                           1                                    0   300
# 36597                           0                                    1   300
#
# [15784 rows x 9 columns]
